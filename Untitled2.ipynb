# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Seaborn" data-toc-modified-id="Seaborn-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Seaborn</a></span><ul class="toc-item"><li><span><a href="#Introducton-of-Seaborn" data-toc-modified-id="Introducton-of-Seaborn-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Introducton of Seaborn</a></span></li><li><span><a href="#Import-Library" data-toc-modified-id="Import-Library-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Import Library</a></span></li><li><span><a href="#Import-Data-Set." data-toc-modified-id="Import-Data-Set.-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Import Data Set.</a></span></li></ul></li><li><span><a href="#Count-Plot" data-toc-modified-id="Count-Plot-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Count Plot</a></span></li><li><span><a href="#Pie-Plot" data-toc-modified-id="Pie-Plot-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Pie Plot</a></span></li><li><span><a href="#Scatter-plot" data-toc-modified-id="Scatter-plot-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Scatter plot</a></span><ul class="toc-item"><li><span><a href="#Basic-Scatter-Plot" data-toc-modified-id="Basic-Scatter-Plot-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Basic Scatter Plot</a></span></li><li><span><a href="#Satter-Plot---Category" data-toc-modified-id="Satter-Plot---Category-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Satter Plot - Category</a></span></li><li><span><a href="#Control-shape-of-element-in-Scatter-Plot" data-toc-modified-id="Control-shape-of-element-in-Scatter-Plot-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Control shape of element in Scatter Plot</a></span></li><li><span><a href="#Using-color-Palletes-in-Scatter-Plot" data-toc-modified-id="Using-color-Palletes-in-Scatter-Plot-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Using color Palletes in Scatter Plot</a></span></li><li><span><a href="#Scatter-Plot-with-Regression-Fit" data-toc-modified-id="Scatter-Plot-with-Regression-Fit-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Scatter Plot with Regression Fit</a></span></li></ul></li><li><span><a href="#Line-Plot" data-toc-modified-id="Line-Plot-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Line Plot</a></span><ul class="toc-item"><li><span><a href="#Basic-Line-Plot" data-toc-modified-id="Basic-Line-Plot-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Basic Line Plot</a></span></li><li><span><a href="#Line-Plot---Category" data-toc-modified-id="Line-Plot---Category-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Line Plot - Category</a></span></li></ul></li><li><span><a href="#Histogram-Plot" data-toc-modified-id="Histogram-Plot-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Histogram Plot</a></span><ul class="toc-item"><li><span><a href="#Basic-Histogram-plot" data-toc-modified-id="Basic-Histogram-plot-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Basic Histogram plot</a></span></li><li><span><a href="#Histogram-Plot-:-Control-Number-of-Bins" data-toc-modified-id="Histogram-Plot-:-Control-Number-of-Bins-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Histogram Plot : Control Number of Bins</a></span></li><li><span><a href="#Histogram-Plot-:-Control-Density" data-toc-modified-id="Histogram-Plot-:-Control-Density-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Histogram Plot : Control Density</a></span><ul class="toc-item"><li><span><a href="#kde=False" data-toc-modified-id="kde=False-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>kde=False</a></span></li><li><span><a href="#kde-=-True" data-toc-modified-id="kde-=-True-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>kde = True</a></span></li></ul></li></ul></li><li><span><a href="#Density-Plot" data-toc-modified-id="Density-Plot-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Density Plot</a></span><ul class="toc-item"><li><span><a href="#1D-Density-Plot" data-toc-modified-id="1D-Density-Plot-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>1D Density Plot</a></span><ul class="toc-item"><li><span><a href="#Basic-1D-Density-Plot" data-toc-modified-id="Basic-1D-Density-Plot-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Basic 1D Density Plot</a></span></li><li><span><a href="#Density-Plot-with-Shade" data-toc-modified-id="Density-Plot-with-Shade-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>Density Plot with Shade</a></span></li><li><span><a href="#Horizontal-Density-Plot" data-toc-modified-id="Horizontal-Density-Plot-7.1.3"><span class="toc-item-num">7.1.3&nbsp;&nbsp;</span>Horizontal Density Plot</a></span></li><li><span><a href="#Horizontal-Density-Plot-with-Shade" data-toc-modified-id="Horizontal-Density-Plot-with-Shade-7.1.4"><span class="toc-item-num">7.1.4&nbsp;&nbsp;</span>Horizontal Density Plot with Shade</a></span></li></ul></li><li><span><a href="#Multi-Variable-Density-Plot" data-toc-modified-id="Multi-Variable-Density-Plot-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Multi Variable Density Plot</a></span></li><li><span><a href="#Multi-Variable-Density-Plot:-Customize-Color" data-toc-modified-id="Multi-Variable-Density-Plot:-Customize-Color-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Multi Variable Density Plot: Customize Color</a></span></li><li><span><a href="#2D-Density-Plot" data-toc-modified-id="2D-Density-Plot-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>2D Density Plot</a></span><ul class="toc-item"><li><span><a href="#Basic-2D-Density-Plot" data-toc-modified-id="Basic-2D-Density-Plot-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>Basic 2D Density Plot</a></span></li></ul></li></ul></li><li><span><a href="#Bar-Plot" data-toc-modified-id="Bar-Plot-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Bar Plot</a></span><ul class="toc-item"><li><span><a href="#Basic-Bar-Plot" data-toc-modified-id="Basic-Bar-Plot-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Basic Bar Plot</a></span></li><li><span><a href="#Horizontal-Bar-Plot" data-toc-modified-id="Horizontal-Bar-Plot-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Horizontal Bar Plot</a></span></li></ul></li><li><span><a href="#Box-Plot" data-toc-modified-id="Box-Plot-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Box Plot</a></span><ul class="toc-item"><li><span><a href="#Basic-Box-Plot" data-toc-modified-id="Basic-Box-Plot-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Basic Box Plot</a></span></li><li><span><a href="#Box-Plot---Category" data-toc-modified-id="Box-Plot---Category-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Box Plot - Category</a></span></li></ul></li><li><span><a href="#Heatmap" data-toc-modified-id="Heatmap-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Heatmap</a></span></li><li><span><a href="#Violin-Plot" data-toc-modified-id="Violin-Plot-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Violin Plot</a></span><ul class="toc-item"><li><span><a href="#Basic-Violin-Plot" data-toc-modified-id="Basic-Violin-Plot-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Basic Violin Plot</a></span></li><li><span><a href="#Violin-Plot---Category" data-toc-modified-id="Violin-Plot---Category-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Violin Plot - Category</a></span></li><li><span><a href="#Horizontal-Violin-Plot" data-toc-modified-id="Horizontal-Violin-Plot-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Horizontal Violin Plot</a></span></li><li><span><a href="#Horizontal-Violin-Plot---Category" data-toc-modified-id="Horizontal-Violin-Plot---Category-11.4"><span class="toc-item-num">11.4&nbsp;&nbsp;</span>Horizontal Violin Plot - Category</a></span></li></ul></li><li><span><a href="#Seaborn-Themes" data-toc-modified-id="Seaborn-Themes-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Seaborn Themes</a></span><ul class="toc-item"><li><span><a href="#Dark-Grid" data-toc-modified-id="Dark-Grid-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span>Dark Grid</a></span></li><li><span><a href="#White-Grid" data-toc-modified-id="White-Grid-12.2"><span class="toc-item-num">12.2&nbsp;&nbsp;</span>White Grid</a></span></li><li><span><a href="#dark" data-toc-modified-id="dark-12.3"><span class="toc-item-num">12.3&nbsp;&nbsp;</span>dark</a></span></li><li><span><a href="#White" data-toc-modified-id="White-12.4"><span class="toc-item-num">12.4&nbsp;&nbsp;</span>White</a></span></li><li><span><a href="#Ticks" data-toc-modified-id="Ticks-12.5"><span class="toc-item-num">12.5&nbsp;&nbsp;</span>Ticks</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Seaborn

# %% [markdown]
# ## Introducton of Seaborn
#
# - Seaborn is a library for making statistical graphics in Python.
# - It builds on top of matplotlib and integrates closely with pandas data structures.
# - Its plotting functions operate on dataframes and arrays containing whole datasets and internally perform the necessary semantic mapping and statistical aggregation to produce informative plots.
# - Its dataset-oriented, declarative API lets you focus on what the different elements of your plots mean, rather than on the details of how to draw them.

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Data Set.

# %%
from sklearn.datasets import load_iris
iris = load_iris()

x = pd.DataFrame(iris['data'],columns=iris.feature_names)
x.head()

y = pd.DataFrame(iris.target,columns=['target'])
y.head()

df = pd.concat([x,y],axis=1)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# # Count Plot

# %%
sns.countplot(x='target',data=df)

# %%
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()

x = pd.DataFrame(cancer['data'],columns=cancer.feature_names)

y = pd.DataFrame(cancer.target,columns=['target'])

df_cancer = pd.concat([x,y],axis=1)
df_cancer.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
colors = ['#0101DF','#DF0101']
sns.countplot(x='target',data=df_cancer,palette=colors)
plt.title("Cancer Status Distribution \n (0 : Not Cancer || 1: Cancer)",fontsize=14)
# Out:
# Text(0.5, 1.0, 'Cancer Status Distribution \n (0 : Not Cancer || 1: Cancer)')

# %% [markdown]
# # Pie Plot

# %%
df_cancer['target'].value_counts().plot.pie(explode=[0,0.1],labels=['Cancer','Not Cancer'],autopct='%1.1f%%',startangle=90)

# %% [markdown]
# # Scatter plot

# %% [markdown]
# ## Basic Scatter Plot

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
sns.scatterplot(x="sepal length (cm)",y='sepal width (cm)',data=df)
plt.title("Sepal Length Vs Sepal Width")
# Out:
# Text(0.5, 1.0, 'Sepal Length Vs Sepal Width')

# %% [markdown]
# ## Satter Plot - Category

# %%
sns.scatterplot(x='sepal length (cm)',y='sepal width (cm)',hue='target',data=df)
plt.title("Sepal Length Vs Sepal Width")
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)

# %% [markdown]
# ## Control shape of element in Scatter Plot

# %%
sns.scatterplot(x="sepal length (cm)",y="sepal width (cm)",hue='target',data=df, marker='+')
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)
plt.title("Sepal Length Vs Sepal Width")
# Out:
# Text(0.5, 1.0, 'Sepal Length Vs Sepal Width')

# %% [markdown]
# ## Using color Palletes in Scatter Plot

# %%
url = "https://raw.githubusercontent.com/UBC-MDS/DSCI_522_OlympicMedalPrediction/master/data/athlete_events.csv"
olympic = pd.read_csv(url)
olympic.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
sns.scatterplot(x='Age',y="Height",hue='Sex',data=olympic,palette='Blues')
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)
plt.title("Age Vs Height")
# Out:
# Text(0.5, 1.0, 'Age Vs Height')

# %%
sns.scatterplot(x='Age',y="Height",hue='Sex',data=olympic,palette='PuOr')
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)
plt.title("Age Vs Height")
# Out:
# Text(0.5, 1.0, 'Age Vs Height')

# %%
sns.scatterplot(x='Age',y="Height",hue='Sex',data=olympic,palette='Set1')
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)
plt.title("Age Vs Height")
# Out:
# Text(0.5, 1.0, 'Age Vs Height')

# %%
sns.scatterplot(x='Age',y="Height",hue='Sex',data=olympic,palette='Set2')
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)
plt.title("Age Vs Height")
# Out:
# Text(0.5, 1.0, 'Age Vs Height')

# %% [markdown]
# ## Scatter Plot with Regression Fit

# %%
sns.regplot(x='Age',y='Height',data=olympic)
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)
plt.title("Age Vs Height with Regression Fit")
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'Age Vs Height with Regression Fit')

# %%
sns.regplot(x='sepal length (cm)',y='sepal width (cm)',data=df)
plt.title("Sepal Length Vs Sepal Width with Regression Fit",size=15)
# Out:
# Text(0.5, 1.0, 'Sepal Length Vs Sepal Width with Regression Fit')

# %% [markdown]
# # Line Plot

# %% [markdown]
# ## Basic Line Plot

# %%
sns.lineplot(x = 'Age',y='Height',data=olympic)
plt.title("Age Vs Height With Line Plot")
# Out:
# Text(0.5, 1.0, 'Age Vs Height With Line Plot')

# %% [markdown]
# ## Line Plot - Category

# %%
sns.lineplot(x="Age",y="Height",hue="Sex",data=olympic)
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)
plt.title("Age Vs Height",size=15)
# Out:
# Text(0.5, 1.0, 'Age Vs Height')

# %%
sns.lineplot(x="Age",y='Height',data=olympic,estimator=None)

# %% [markdown]
# # Histogram Plot

# %% [markdown]
# ## Basic Histogram plot

# %%
f,ax=plt.subplots(figsize=(7,5))
sns.despine(f)
sns.distplot(olympic['Age'])

# %% [markdown]
# ## Histogram Plot : Control Number of Bins

# %%
f,ax = plt.subplots(figsize=(7,5))
sns.despine(f)
sns.distplot(olympic['Age'],bins=20)

# %% [markdown]
# ## Histogram Plot : Control Density

# %% [markdown]
# ### kde=False

# %%
f,ax = plt.subplots(figsize=(7,5))
sns.despine(f)
sns.distplot(olympic['Age'],kde=False)

# %% [markdown]
# ### kde = True

# %%
f,ax = plt.subplots(figsize=(7,5))
sns.despine(f)
sns.distplot(olympic['Age'],kde=True)

# %% [markdown]
# # Density Plot

# %% [markdown]
# ## 1D Density Plot

# %% [markdown]
# ### Basic 1D Density Plot

# %%
f,ax = plt.subplots(figsize=(7,5))
sns.despine(f)
sns.kdeplot(olympic['Age'])

# %% [markdown]
# ### Density Plot with Shade

# %%
f,ax = plt.subplots(figsize=(7,5))
sns.despine(f)
sns.kdeplot(olympic['Age'],shade=True)

# %% [markdown]
# ### Horizontal Density Plot

# %%
f,ax = plt.subplots(figsize=(7,5))
sns.despine(f)
sns.kdeplot(olympic['Age'],vertical=True)

# %% [markdown]
# ### Horizontal Density Plot with Shade

# %%
f,ax = plt.subplots(figsize=(7,5))
sns.despine(f)
sns.kdeplot(olympic['Age'],vertical=True,shade=True)

# %% [markdown]
# ## Multi Variable Density Plot

# %%
f,ax = plt.subplots(figsize=(7,5))
sns.despine(f)
sns.kdeplot(olympic['Age'],shade=True)
sns.kdeplot(olympic['Height'],shade=True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.kdeplot(df['petal width (cm)'], shade=True)
sns.kdeplot(df['petal length (cm)'], shade=True)
plt.show()

# %% [markdown]
# ## Multi Variable Density Plot: Customize Color

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.kdeplot(df['petal width (cm)'], shade=True, color='r')
sns.kdeplot(df['petal length (cm)'], shade=True, color='m')
plt.show()

# %% [markdown]
# ## 2D Density Plot

# %% [markdown]
# ### Basic 2D Density Plot

# %%
sns.kdeplot(df['sepal length (cm)'],df['sepal width (cm)'])
plt.title('Sepal Length Vs Sepal Width With 2D Density Plot')
# Out:
# Text(0.5, 1.0, 'Sepal Length Vs Sepal Width With 2D Density Plot')

# %%
sns.kdeplot(df['sepal length (cm)'],df['sepal width (cm)'],cmap='Reds',shade=True,bw=.15)

# %%
sns.kdeplot(df['sepal length (cm)'],df['sepal width (cm)'],shade=True,cmap='Blues',shade_lowest=True)

# %% [markdown]
# # Bar Plot

# %% [markdown]
# ## Basic Bar Plot

# %%
f, ax = plt.subplots(figsize=(7,5))
sns.despine(f)
sns.barplot(df['target'],df['sepal length (cm)'],palette='magma')

# %% [markdown]
# ## Horizontal Bar Plot

# %%
f, ax = plt.subplots(figsize=(7,5))
sns.despine(f)
sns.barplot(y=df['target'],x=df['sepal length (cm)'],palette='magma',orient='h')

# %% [markdown]
# # Box Plot

# %% [markdown]
# ## Basic Box Plot

# %%
sns.boxplot(y=olympic['Age'])
plt.show()

# %% [markdown]
# ## Box Plot - Category

# %%
sns.boxplot(x=olympic['Sex'],y=olympic['Height'])
plt.show()

# %% [markdown]
# # Heatmap

# %%
sns.heatmap(df.corr())

# %%
sns.heatmap(df.corr(),annot=True)

# %%
sns.heatmap(df.corr(),annot=True,cmap='Set3')

# %% [markdown]
# # Violin Plot

# %% [markdown]
# ## Basic Violin Plot

# %%
sns.violinplot(y=olympic['Age'])

# %% [markdown]
# ## Violin Plot - Category

# %%
sns.violinplot(x=olympic['Sex'],y=olympic['Age'])

# %% [markdown]
# ## Horizontal Violin Plot

# %%
sns.violinplot(x=olympic['Age'])

# %% [markdown]
# ## Horizontal Violin Plot - Category

# %%
sns.violinplot(y=olympic['Sex'],x=olympic['Age'])

# %%
sns.violinplot(data=df.iloc[:,0:4])

# %% [markdown]
# # Seaborn Themes

# %% [markdown]
# - Seaborn has five built-in themes to style its plots:
#                         1. darkgrid
#                         2. whitegrid
#                         3. dark
#                         4. white
#                         5. ticks
# - Seaborn defaults to using the darkgrid theme for its plots, but you can change this styling to better suit your presentation needs.
# - To use any of the preset themes pass the name of it to :
#
#                                       sns.set_style()

# %% [markdown]
# ## Dark Grid

# %%
sns.set_style("darkgrid")
sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', data=df)
plt.title("Seaborn Dark Grid Theme")
# Out:
# Text(0.5, 1.0, 'Seaborn Dark Grid Theme')

# %% [markdown]
# ## White Grid

# %%
sns.set_style("whitegrid")
sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', data=df)
plt.title("Seaborn Dark Grid Theme")
# Out:
# Text(0.5, 1.0, 'Seaborn Dark Grid Theme')

# %% [markdown]
# ## dark

# %%
sns.set_style("dark")
sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', data=df)
plt.title("Seaborn Dark Grid Theme")
# Out:
# Text(0.5, 1.0, 'Seaborn Dark Grid Theme')

# %% [markdown]
# ## White

# %%
sns.set_style("white")
sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', data=df)
plt.title("Seaborn Dark Grid Theme")
# Out:
# Text(0.5, 1.0, 'Seaborn Dark Grid Theme')

# %% [markdown]
# ## Ticks

# %%
sns.set_style("ticks")
sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', data=df)
plt.title("Seaborn Dark Grid Theme")
# Out:
# Text(0.5, 1.0, 'Seaborn Dark Grid Theme')
